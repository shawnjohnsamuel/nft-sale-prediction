# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

import requests
from keys import opensea_key
from pandas.io.json import json_normalize
# pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
#initial grab of assets, no parameters
print('***************************************')
print('assets_1: initial import, no parameters')
print('***************************************')
list_of_asset_dfs_1 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_1.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_1 = pd.concat([df for df in list_of_asset_dfs_1], ignore_index = True, sort=False)
print("")
print("")


#another pull with no assets to see if there is significant overlap
print("")
print('**************************************')
print('assets_2: second import, no parameters')
print('**************************************')
list_of_asset_dfs_2 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_2.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_2 = pd.concat([df for df in list_of_asset_dfs_2], ignore_index = True, sort=False)
print("")
print("")


#as per API instructions, using the "current_escrow_price" ordering to include 
#secondary sales market and cryptokitties
print("")
print('********************************************')
print('assets_3: sort by current_escrow_price, desc')
list_of_asset_dfs_3 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"current_escrow_price","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_3.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_3 = pd.concat([df for df in list_of_asset_dfs_3], ignore_index = True, sort=False)
print("")
print("")


print("")
print('*******************************************')
print('assets_4: sort by current_escrow_price, asc')
print('*******************************************')
list_of_asset_dfs_4 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"current_escrow_price","order_direction":"asc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_4.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_4 = pd.concat([df for df in list_of_asset_dfs_4], ignore_index = True, sort=False)
print("")
print("")


print("")
print('*************************************')
print('assets_5: sort by visitor_count, desc')
print('*************************************')
list_of_asset_dfs_5 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"visitor_count","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_5.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_5 = pd.concat([df for df in list_of_asset_dfs_5], ignore_index = True, sort=False)
print("")
print("")


print("")
print('************************************')
print('assets_6: sort by visitor_count, asc')
print('************************************')
list_of_asset_dfs_6 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"visitor_count","order_direction":"asc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_6.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_6 = pd.concat([df for df in list_of_asset_dfs_6], ignore_index = True, sort=False)
print("")
print("")


print("")
print('**********************************')
print('assets_7: sort by sale_count, desc')
print('**********************************')
list_of_asset_dfs_7 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"sale_count","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_7.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_7 = pd.concat([df for df in list_of_asset_dfs_7], ignore_index = True, sort=False)
print("")
print("")


print("")
print('**********************************')
print('assets_8: sort by sale_price, desc')
print('**********************************')
list_of_asset_dfs_8 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"sale_count","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_8.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_8 = pd.concat([df for df in list_of_asset_dfs_8], ignore_index = True, sort=False)
print("")
print("")


print("")
print('****************************')
print('assets_9: listing_date, desc')
print('****************************')
list_of_asset_dfs_9 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"listing_date","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_9.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_9 = pd.concat([df for df in list_of_asset_dfs_9], ignore_index = True, sort=False)
print("")
print("")


print("")
print('*****************************')
print('assets_10: listing_date, desc')
print('*****************************')
list_of_asset_dfs_10 = []
for offset in range(0,10050,50):
    url = "https://api.opensea.io/api/v1/assets"
    querystring = {"order_by":"listing_date","order_direction":"desc", "offset":f"{offset}","limit":"50"}
    headers = {"X-API-KEY": opensea_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    json = response.json()
    df = json_normalize(json['assets'], max_level=4)
    list_of_asset_dfs_10.append(df)
    print(f"Offset is {offset} and {len(df)} assets added")
assets_10 = pd.concat([df for df in list_of_asset_dfs_10], ignore_index = True, sort=False)
print("")
print("")
# Out:
# ***************************************
# assets_1: initial import, no parameters
# ***************************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# **************************************
# assets_2: second import, no parameters
# **************************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# ********************************************
# assets_3: sort by current_escrow_price, desc
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# *******************************************
# assets_4: sort by current_escrow_price, asc
# *******************************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# *************************************
# assets_5: sort by visitor_count, desc
# *************************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# ************************************
# assets_6: sort by visitor_count, asc
# ************************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# **********************************
# assets_7: sort by sale_count, desc
# **********************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# ...
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# ****************************
# assets_9: listing_date, desc
# ****************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added
#
#
#
# *****************************
# assets_10: listing_date, desc
# *****************************
# Offset is 0 and 50 assets added
# Offset is 50 and 50 assets added
# Offset is 100 and 50 assets added
# Offset is 150 and 50 assets added
# Offset is 200 and 50 assets added
# Offset is 250 and 50 assets added
# Offset is 300 and 50 assets added
# Offset is 350 and 50 assets added
# Offset is 400 and 50 assets added
# Offset is 450 and 50 assets added
# Offset is 500 and 50 assets added
# Offset is 550 and 50 assets added
# Offset is 600 and 50 assets added
# Offset is 650 and 50 assets added
# Offset is 700 and 50 assets added
# Offset is 750 and 50 assets added
# Offset is 800 and 50 assets added
# Offset is 850 and 50 assets added
# Offset is 900 and 50 assets added
# Offset is 950 and 50 assets added
# Offset is 1000 and 50 assets added
# Offset is 1050 and 50 assets added
# Offset is 1100 and 50 assets added
# Offset is 1150 and 50 assets added
# Offset is 1200 and 50 assets added
# Offset is 1250 and 50 assets added
# Offset is 1300 and 50 assets added
# Offset is 1350 and 50 assets added
# Offset is 1400 and 50 assets added
# Offset is 1450 and 50 assets added
# Offset is 1500 and 50 assets added
# Offset is 1550 and 50 assets added
# Offset is 1600 and 50 assets added
# Offset is 1650 and 50 assets added
# Offset is 1700 and 50 assets added
# Offset is 1750 and 50 assets added
# Offset is 1800 and 50 assets added
# Offset is 1850 and 50 assets added
# Offset is 1900 and 50 assets added
# Offset is 1950 and 50 assets added
# Offset is 2000 and 50 assets added
# Offset is 2050 and 50 assets added
# Offset is 2100 and 50 assets added
# Offset is 2150 and 50 assets added
# Offset is 2200 and 50 assets added
# Offset is 2250 and 50 assets added
# Offset is 2300 and 50 assets added
# Offset is 2350 and 50 assets added
# Offset is 2400 and 50 assets added
# Offset is 2450 and 50 assets added
# Offset is 2500 and 50 assets added
# Offset is 2550 and 50 assets added
# Offset is 2600 and 50 assets added
# Offset is 2650 and 50 assets added
# Offset is 2700 and 50 assets added
# Offset is 2750 and 50 assets added
# Offset is 2800 and 50 assets added
# Offset is 2850 and 50 assets added
# Offset is 2900 and 50 assets added
# Offset is 2950 and 50 assets added
# Offset is 3000 and 50 assets added
# Offset is 3050 and 50 assets added
# Offset is 3100 and 50 assets added
# Offset is 3150 and 50 assets added
# Offset is 3200 and 50 assets added
# Offset is 3250 and 50 assets added
# Offset is 3300 and 50 assets added
# Offset is 3350 and 50 assets added
# Offset is 3400 and 50 assets added
# Offset is 3450 and 50 assets added
# Offset is 3500 and 50 assets added
# Offset is 3550 and 50 assets added
# Offset is 3600 and 50 assets added
# Offset is 3650 and 50 assets added
# Offset is 3700 and 50 assets added
# Offset is 3750 and 50 assets added
# Offset is 3800 and 50 assets added
# Offset is 3850 and 50 assets added
# Offset is 3900 and 50 assets added
# Offset is 3950 and 50 assets added
# Offset is 4000 and 50 assets added
# Offset is 4050 and 50 assets added
# Offset is 4100 and 50 assets added
# Offset is 4150 and 50 assets added
# Offset is 4200 and 50 assets added
# Offset is 4250 and 50 assets added
# Offset is 4300 and 50 assets added
# Offset is 4350 and 50 assets added
# Offset is 4400 and 50 assets added
# Offset is 4450 and 50 assets added
# Offset is 4500 and 50 assets added
# Offset is 4550 and 50 assets added
# Offset is 4600 and 50 assets added
# Offset is 4650 and 50 assets added
# Offset is 4700 and 50 assets added
# Offset is 4750 and 50 assets added
# Offset is 4800 and 50 assets added
# Offset is 4850 and 50 assets added
# Offset is 4900 and 50 assets added
# Offset is 4950 and 50 assets added
# Offset is 5000 and 50 assets added
# Offset is 5050 and 50 assets added
# Offset is 5100 and 50 assets added
# Offset is 5150 and 50 assets added
# Offset is 5200 and 50 assets added
# Offset is 5250 and 50 assets added
# Offset is 5300 and 50 assets added
# Offset is 5350 and 50 assets added
# Offset is 5400 and 50 assets added
# Offset is 5450 and 50 assets added
# Offset is 5500 and 50 assets added
# Offset is 5550 and 50 assets added
# Offset is 5600 and 50 assets added
# Offset is 5650 and 50 assets added
# Offset is 5700 and 50 assets added
# Offset is 5750 and 50 assets added
# Offset is 5800 and 50 assets added
# Offset is 5850 and 50 assets added
# Offset is 5900 and 50 assets added
# Offset is 5950 and 50 assets added
# Offset is 6000 and 50 assets added
# Offset is 6050 and 50 assets added
# Offset is 6100 and 50 assets added
# Offset is 6150 and 50 assets added
# Offset is 6200 and 50 assets added
# Offset is 6250 and 50 assets added
# Offset is 6300 and 50 assets added
# Offset is 6350 and 50 assets added
# Offset is 6400 and 50 assets added
# Offset is 6450 and 50 assets added
# Offset is 6500 and 50 assets added
# Offset is 6550 and 50 assets added
# Offset is 6600 and 50 assets added
# Offset is 6650 and 50 assets added
# Offset is 6700 and 50 assets added
# Offset is 6750 and 50 assets added
# Offset is 6800 and 50 assets added
# Offset is 6850 and 50 assets added
# Offset is 6900 and 50 assets added
# Offset is 6950 and 50 assets added
# Offset is 7000 and 50 assets added
# Offset is 7050 and 50 assets added
# Offset is 7100 and 50 assets added
# Offset is 7150 and 50 assets added
# Offset is 7200 and 50 assets added
# Offset is 7250 and 50 assets added
# Offset is 7300 and 50 assets added
# Offset is 7350 and 50 assets added
# Offset is 7400 and 50 assets added
# Offset is 7450 and 50 assets added
# Offset is 7500 and 50 assets added
# Offset is 7550 and 50 assets added
# Offset is 7600 and 50 assets added
# Offset is 7650 and 50 assets added
# Offset is 7700 and 50 assets added
# Offset is 7750 and 50 assets added
# Offset is 7800 and 50 assets added
# Offset is 7850 and 50 assets added
# Offset is 7900 and 50 assets added
# Offset is 7950 and 50 assets added
# Offset is 8000 and 50 assets added
# Offset is 8050 and 50 assets added
# Offset is 8100 and 50 assets added
# Offset is 8150 and 50 assets added
# Offset is 8200 and 50 assets added
# Offset is 8250 and 50 assets added
# Offset is 8300 and 50 assets added
# Offset is 8350 and 50 assets added
# Offset is 8400 and 50 assets added
# Offset is 8450 and 50 assets added
# Offset is 8500 and 50 assets added
# Offset is 8550 and 50 assets added
# Offset is 8600 and 50 assets added
# Offset is 8650 and 50 assets added
# Offset is 8700 and 50 assets added
# Offset is 8750 and 50 assets added
# Offset is 8800 and 50 assets added
# Offset is 8850 and 50 assets added
# Offset is 8900 and 50 assets added
# Offset is 8950 and 50 assets added
# Offset is 9000 and 50 assets added
# Offset is 9050 and 50 assets added
# Offset is 9100 and 50 assets added
# Offset is 9150 and 50 assets added
# Offset is 9200 and 50 assets added
# Offset is 9250 and 50 assets added
# Offset is 9300 and 50 assets added
# Offset is 9350 and 50 assets added
# Offset is 9400 and 50 assets added
# Offset is 9450 and 50 assets added
# Offset is 9500 and 50 assets added
# Offset is 9550 and 50 assets added
# Offset is 9600 and 50 assets added
# Offset is 9650 and 50 assets added
# Offset is 9700 and 50 assets added
# Offset is 9750 and 50 assets added
# Offset is 9800 and 50 assets added
# Offset is 9850 and 50 assets added
# Offset is 9900 and 50 assets added
# Offset is 9950 and 50 assets added
# Offset is 10000 and 50 assets added

# %%
assets = pd.concat([assets_1, assets_2, assets_3, assets_4,
                    assets_5, assets_6, assets_7, assets_8, 
                    assets_9, assets_10], ignore_index=True, sort=False)

# %%
print(f"assets_1: {assets_1['id'].nunique()}")
print(f"assets_2: {assets_2['id'].nunique()}")
print(f"assets_3: {assets_3['id'].nunique()}")
print(f"assets_4: {assets_4['id'].nunique()}")
print(f"assets_5: {assets_5['id'].nunique()}")
print(f"assets_6: {assets_6['id'].nunique()}")
print(f"assets_7: {assets_7['id'].nunique()}")
print(f"assets_8: {assets_8['id'].nunique()}")
print(f"assets_9: {assets_9['id'].nunique()}")
print(f"assets_10: {assets_10['id'].nunique()}")
print(f"total unique assets: {assets['id'].nunique()}")
# Out:
# assets_1: 9895
# assets_2: 9895
# assets_3: 9879
# assets_4: 10050
# assets_5: 9847
# assets_6: 7988
# assets_7: 7885
# assets_8: 7885
# assets_9: 9951
# assets_10: 9951
# total unique assets: 41055

# %%
assets_2['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_3['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_4['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_5['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_6['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_7['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_8['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_9['asset_contract.created_date'].astype("datetime64").dt.year.hist()
assets_10['asset_contract.created_date'].astype("datetime64").dt.year.hist()

# %%
assets['asset_contract.created_date'].astype("datetime64").dt.year.hist()

# %%
print(f"{assets['id'].nunique()} unique ids: ")
print(f"{assets['token_id'].nunique()} unique token_ids")
# Out:
# 41055 unique ids:
# 36101 unique token_ids

# %%
df = assets.drop_duplicates(subset=['token_id'])

# %%
print(f"{df['id'].nunique()} unique ids: ")
print(f"{df['token_id'].nunique()} unique token_ids")
# Out:
# 36101 unique ids:
# 36101 unique token_ids

# %%
df['asset_contract.created_date'].astype("datetime64").dt.year.hist()

# %%
df.to_csv('../data/1b_data_initial_validation_set.csv', index=False)
