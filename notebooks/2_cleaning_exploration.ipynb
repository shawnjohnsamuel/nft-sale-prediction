# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ### Data

# %%
parse_dates = ['listing_date', 
               'asset_contract.created_date', 
               'collection.created_date', 
               'last_sale.created_date']
df_full = pd.read_csv('../data/1_data_initial.csv', low_memory=False, parse_dates=parse_dates)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44752 entries, 0 to 44751
# Columns: 133 entries, id to transfer_fee_payment_token.usd_price
# dtypes: bool(9), datetime64[ns](4), float64(26), int64(12), object(82)
# memory usage: 42.7+ MB

# %%
df_full.head()
# Out:
#          id                                           token_id  num_sales  \
# 0  30033345  9132198125583360689797322472203169750011716430...          0
# 1  30033344  3268304683559065074852929730958675774624902165...          0
# 2  30033343  7779220728716121010175700030620486582973273824...          0
# 3  30033342  9510190511962339173712504282354773321324120343...          0
# 4  30033341  1029511648543007736247727748847500291464805430...          0
#
#   background_color                                          image_url  \
# 0              NaN  https://storage.opensea.io/files/b09d044f17573...
# 1              NaN  https://lh3.googleusercontent.com/P7NXQatzHWTt...
# 2              NaN  https://lh3.googleusercontent.com/qCzcK3sEGp2R...
# 3              NaN  https://lh3.googleusercontent.com/iDHrRY_ko62L...
# 4              NaN  https://lh3.googleusercontent.com/LrBXq8LND7W-...
#
#                                    image_preview_url  \
# 0  https://storage.opensea.io/files/b09d044f17573...
# 1  https://lh3.googleusercontent.com/P7NXQatzHWTt...
# 2  https://lh3.googleusercontent.com/qCzcK3sEGp2R...
# 3  https://lh3.googleusercontent.com/iDHrRY_ko62L...
# 4  https://lh3.googleusercontent.com/LrBXq8LND7W-...
#
#                                  image_thumbnail_url image_original_url  \
# 0  https://storage.opensea.io/files/b09d044f17573...                NaN
# 1  https://lh3.googleusercontent.com/P7NXQatzHWTt...                NaN
# 2  https://lh3.googleusercontent.com/qCzcK3sEGp2R...                NaN
# 3  https://lh3.googleusercontent.com/iDHrRY_ko62L...                NaN
# 4  https://lh3.googleusercontent.com/LrBXq8LND7W-...                NaN
#
#   animation_url animation_original_url  ...  \
# 0           NaN                    NaN  ...
# 1           NaN                    NaN  ...
# 2           NaN                    NaN  ...
# 3           NaN                    NaN  ...
# 4           NaN                    NaN  ...
#
#   last_sale.transaction.from_account.user  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   last_sale.transaction.to_account.user transfer_fee_payment_token.id  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
#
#   transfer_fee_payment_token.symbol  transfer_fee_payment_token.address  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   transfer_fee_payment_token.image_url transfer_fee_payment_token.name  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#   transfer_fee_payment_token.decimals  transfer_fee_payment_token.eth_price  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#    transfer_fee_payment_token.usd_price
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 133 columns]

# %%
df_full.id.nunique()
# Out:
# 44752

# %%
df_full.token_id.nunique()
# Out:
# 44752

# %%
list(df_full.columns)
# Out:
# ['id',
#  'token_id',
#  'num_sales',
#  'background_color',
#  'image_url',
#  'image_preview_url',
#  'image_thumbnail_url',
#  'image_original_url',
#  'animation_url',
#  'animation_original_url',
#  'name',
#  'description',
#  'external_link',
#  'permalink',
#  'decimals',
#  'token_metadata',
#  'sell_orders',
#  'traits',
#  'last_sale',
#  'top_bid',
#  'listing_date',
#  'is_presale',
#  'transfer_fee_payment_token',
#  'transfer_fee',
#  'asset_contract.address',
#  'asset_contract.asset_contract_type',
#  'asset_contract.created_date',
#  'asset_contract.name',
#  'asset_contract.nft_version',
#  'asset_contract.opensea_version',
#  'asset_contract.owner',
#  'asset_contract.schema_name',
#  'asset_contract.symbol',
#  'asset_contract.total_supply',
#  'asset_contract.description',
#  'asset_contract.external_link',
#  'asset_contract.image_url',
#  'asset_contract.default_to_fiat',
#  'asset_contract.dev_buyer_fee_basis_points',
#  'asset_contract.dev_seller_fee_basis_points',
#  'asset_contract.only_proxied_transfers',
#  'asset_contract.opensea_buyer_fee_basis_points',
#  'asset_contract.opensea_seller_fee_basis_points',
#  'asset_contract.buyer_fee_basis_points',
#  'asset_contract.seller_fee_basis_points',
#  'asset_contract.payout_address',
#  'collection.banner_image_url',
#  'collection.chat_url',
#  'collection.created_date',
#  'collection.default_to_fiat',
#  'collection.description',
#  'collection.dev_buyer_fee_basis_points',
#  'collection.dev_seller_fee_basis_points',
#  'collection.discord_url',
#  'collection.display_data.card_display_style',
#  'collection.external_url',
#  'collection.featured',
#  'collection.featured_image_url',
#  'collection.hidden',
#  'collection.safelist_request_status',
#  'collection.image_url',
#  'collection.is_subject_to_whitelist',
#  'collection.large_image_url',
#  'collection.medium_username',
#  'collection.name',
#  'collection.only_proxied_transfers',
#  'collection.opensea_buyer_fee_basis_points',
#  'collection.opensea_seller_fee_basis_points',
#  'collection.payout_address',
#  'collection.require_email',
#  'collection.short_description',
#  'collection.slug',
#  'collection.telegram_url',
#  'collection.twitter_username',
#  'collection.instagram_username',
#  'collection.wiki_url',
#  'owner.user.username',
#  'owner.profile_img_url',
#  'owner.address',
#  'owner.config',
#  'owner.discord_id',
#  'creator.user.username',
#  'creator.profile_img_url',
#  'creator.address',
#  'creator.config',
#  'creator.discord_id',
#  'collection.display_data.images',
#  'owner.user',
#  'creator.user',
#  'creator',
#  'last_sale.asset.token_id',
#  'last_sale.asset.decimals',
#  'last_sale.asset_bundle',
#  'last_sale.event_type',
#  'last_sale.event_timestamp',
#  'last_sale.auction_type',
#  'last_sale.total_price',
#  'last_sale.payment_token.id',
#  'last_sale.payment_token.symbol',
#  'last_sale.payment_token.address',
#  'last_sale.payment_token.image_url',
#  'last_sale.payment_token.name',
#  'last_sale.payment_token.decimals',
#  'last_sale.payment_token.eth_price',
#  'last_sale.payment_token.usd_price',
#  'last_sale.transaction.block_hash',
#  'last_sale.transaction.block_number',
#  'last_sale.transaction.from_account.user.username',
#  'last_sale.transaction.from_account.profile_img_url',
#  'last_sale.transaction.from_account.address',
#  'last_sale.transaction.from_account.config',
#  'last_sale.transaction.from_account.discord_id',
#  'last_sale.transaction.id',
#  'last_sale.transaction.timestamp',
#  'last_sale.transaction.to_account.user.username',
#  'last_sale.transaction.to_account.profile_img_url',
#  'last_sale.transaction.to_account.address',
#  'last_sale.transaction.to_account.config',
#  'last_sale.transaction.to_account.discord_id',
#  'last_sale.transaction.transaction_hash',
#  'last_sale.transaction.transaction_index',
#  'last_sale.created_date',
#  'last_sale.quantity',
#  'last_sale.transaction.from_account.user',
#  'last_sale.transaction.to_account.user',
#  'transfer_fee_payment_token.id',
#  'transfer_fee_payment_token.symbol',
#  'transfer_fee_payment_token.address',
#  'transfer_fee_payment_token.image_url',
#  'transfer_fee_payment_token.name',
#  'transfer_fee_payment_token.decimals',
#  'transfer_fee_payment_token.eth_price',
#  'transfer_fee_payment_token.usd_price']

# %%
# checking for percentage of null values

for column in list(df_full.columns):
    print(f"{df_full[str(column)].isna().sum()/len(df_full):.2%} of {column} is NAN")
# Out:
# 0.00% of id is NAN
# 0.00% of token_id is NAN
# 0.00% of num_sales is NAN
# 52.59% of background_color is NAN
# 10.55% of image_url is NAN
# 10.55% of image_preview_url is NAN
# 10.55% of image_thumbnail_url is NAN
# 40.96% of image_original_url is NAN
# 94.03% of animation_url is NAN
# 94.00% of animation_original_url is NAN
# 19.40% of name is NAN
# 24.60% of description is NAN
# 59.36% of external_link is NAN
# 0.00% of permalink is NAN
# 88.87% of decimals is NAN
# 84.70% of token_metadata is NAN
# 77.54% of sell_orders is NAN
# 0.00% of traits is NAN
# 100.00% of last_sale is NAN
# 100.00% of top_bid is NAN
# 100.00% of listing_date is NAN
# 0.00% of is_presale is NAN
# 100.00% of transfer_fee_payment_token is NAN
# 99.90% of transfer_fee is NAN
# 0.00% of asset_contract.address is NAN
# 0.00% of asset_contract.asset_contract_type is NAN
# 0.00% of asset_contract.created_date is NAN
# 0.00% of asset_contract.name is NAN
# 32.93% of asset_contract.nft_version is NAN
# 71.42% of asset_contract.opensea_version is NAN
# 13.35% of asset_contract.owner is NAN
# 0.00% of asset_contract.schema_name is NAN
# 26.89% of asset_contract.symbol is NAN
# 70.45% of asset_contract.total_supply is NAN
# 39.89% of asset_contract.description is NAN
# 39.50% of asset_contract.external_link is NAN
# 39.29% of asset_contract.image_url is NAN
# 0.00% of asset_contract.default_to_fiat is NAN
# 0.00% of asset_contract.dev_buyer_fee_basis_points is NAN
# 0.00% of asset_contract.dev_seller_fee_basis_points is NAN
# 0.00% of asset_contract.only_proxied_transfers is NAN
# 0.00% of asset_contract.opensea_buyer_fee_basis_points is NAN
# 0.00% of asset_contract.opensea_seller_fee_basis_points is NAN
# 0.00% of asset_contract.buyer_fee_basis_points is NAN
# 0.00% of asset_contract.seller_fee_basis_points is NAN
# 90.76% of asset_contract.payout_address is NAN
# 18.99% of collection.banner_image_url is NAN
# 97.89% of collection.chat_url is NAN
# 0.00% of collection.created_date is NAN
# 0.00% of collection.default_to_fiat is NAN
# 12.19% of collection.description is NAN
# 0.00% of collection.dev_buyer_fee_basis_points is NAN
# 0.00% of collection.dev_seller_fee_basis_points is NAN
# 39.94% of collection.discord_url is NAN
# 10.73% of collection.display_data.card_display_style is NAN
# 27.51% of collection.external_url is NAN
# 0.00% of collection.featured is NAN
# 28.90% of collection.featured_image_url is NAN
# 0.00% of collection.hidden is NAN
# 0.00% of collection.safelist_request_status is NAN
# 10.77% of collection.image_url is NAN
# 0.00% of collection.is_subject_to_whitelist is NAN
# 24.65% of collection.large_image_url is NAN
# 92.07% of collection.medium_username is NAN
# 0.00% of collection.name is NAN
# 0.00% of collection.only_proxied_transfers is NAN
# 0.00% of collection.opensea_buyer_fee_basis_points is NAN
# 0.00% of collection.opensea_seller_fee_basis_points is NAN
# 69.30% of collection.payout_address is NAN
# 0.00% of collection.require_email is NAN
# 99.91% of collection.short_description is NAN
# 0.00% of collection.slug is NAN
# 89.06% of collection.telegram_url is NAN
# 25.47% of collection.twitter_username is NAN
# 88.47% of collection.instagram_username is NAN
# 78.02% of collection.wiki_url is NAN
# 37.88% of owner.user.username is NAN
# 0.00% of owner.profile_img_url is NAN
# 0.00% of owner.address is NAN
# 89.35% of owner.config is NAN
# 99.89% of owner.discord_id is NAN
# 54.31% of creator.user.username is NAN
# 0.79% of creator.profile_img_url is NAN
# 0.79% of creator.address is NAN
# 96.27% of creator.config is NAN
# 99.49% of creator.discord_id is NAN
# 85.52% of collection.display_data.images is NAN
# 100.00% of owner.user is NAN
# 100.00% of creator.user is NAN
# 100.00% of creator is NAN
# 64.89% of last_sale.asset.token_id is NAN
# 94.99% of last_sale.asset.decimals is NAN
# 100.00% of last_sale.asset_bundle is NAN
# 64.89% of last_sale.event_type is NAN
# 64.89% of last_sale.event_timestamp is NAN
# 77.85% of last_sale.auction_type is NAN
# 64.89% of last_sale.total_price is NAN
# 64.89% of last_sale.payment_token.id is NAN
# 64.89% of last_sale.payment_token.symbol is NAN
# 64.89% of last_sale.payment_token.address is NAN
# 64.89% of last_sale.payment_token.image_url is NAN
# 64.89% of last_sale.payment_token.name is NAN
# 64.89% of last_sale.payment_token.decimals is NAN
# 64.90% of last_sale.payment_token.eth_price is NAN
# 64.90% of last_sale.payment_token.usd_price is NAN
# 64.89% of last_sale.transaction.block_hash is NAN
# 64.89% of last_sale.transaction.block_number is NAN
# 82.62% of last_sale.transaction.from_account.user.username is NAN
# 64.89% of last_sale.transaction.from_account.profile_img_url is NAN
# 64.89% of last_sale.transaction.from_account.address is NAN
# 97.81% of last_sale.transaction.from_account.config is NAN
# 99.85% of last_sale.transaction.from_account.discord_id is NAN
# 64.89% of last_sale.transaction.id is NAN
# 64.89% of last_sale.transaction.timestamp is NAN
# 69.64% of last_sale.transaction.to_account.user.username is NAN
# 64.89% of last_sale.transaction.to_account.profile_img_url is NAN
# 64.89% of last_sale.transaction.to_account.address is NAN
# 69.72% of last_sale.transaction.to_account.config is NAN
# 100.00% of last_sale.transaction.to_account.discord_id is NAN
# 64.89% of last_sale.transaction.transaction_hash is NAN
# 64.89% of last_sale.transaction.transaction_index is NAN
# 64.89% of last_sale.created_date is NAN
# 67.15% of last_sale.quantity is NAN
# 100.00% of last_sale.transaction.from_account.user is NAN
# 100.00% of last_sale.transaction.to_account.user is NAN
# 99.90% of transfer_fee_payment_token.id is NAN
# 99.90% of transfer_fee_payment_token.symbol is NAN
# 99.90% of transfer_fee_payment_token.address is NAN
# 99.90% of transfer_fee_payment_token.image_url is NAN
# 99.90% of transfer_fee_payment_token.name is NAN
# 99.90% of transfer_fee_payment_token.decimals is NAN
# 99.90% of transfer_fee_payment_token.eth_price is NAN
# 99.90% of transfer_fee_payment_token.usd_price is NAN

# %%
df_isna = pd.DataFrame()

for column in df_full.columns:
    df_isna.loc['Null', column] = f"{df_full[column].isna().sum()/len(df_full):.2%}"
    df_isna.loc['Count', column] = df_full[column].count()
    df_isna.loc['Unique', column] = df_full[column].nunique()

# %%
df_isna
# Out:
#            id token_id num_sales background_color image_url image_preview_url  \
# Null    0.00%    0.00%     0.00%           52.59%    10.55%            10.55%
# Count   44752    44752     44752            21219     40031             40031
# Unique  44752    44752       202               48     28813             28811
#
#        image_thumbnail_url image_original_url animation_url  \
# Null                10.55%             40.96%        94.03%
# Count                40031              26420          2673
# Unique               28811              25526          2231
#
#        animation_original_url  ... last_sale.transaction.from_account.user  \
# Null                   94.00%  ...                                 100.00%
# Count                    2684  ...                                       0
# Unique                   2243  ...                                       0
#
#        last_sale.transaction.to_account.user transfer_fee_payment_token.id  \
# Null                                 100.00%                        99.90%
# Count                                      0                            43
# Unique                                     0                             1
#
#        transfer_fee_payment_token.symbol transfer_fee_payment_token.address  \
# Null                              99.90%                             99.90%
# Count                                 43                                 43
# Unique                                 1                                  1
#
#        transfer_fee_payment_token.image_url transfer_fee_payment_token.name  \
# Null                                 99.90%                          99.90%
# Count                                    43                              43
# Unique                                    1                               1
#
#        transfer_fee_payment_token.decimals  \
# Null                                99.90%
# Count                                   43
# Unique                                   1
#
#        transfer_fee_payment_token.eth_price  \
# Null                                 99.90%
# Count                                    43
# Unique                                    1
#
#        transfer_fee_payment_token.usd_price
# Null                                 99.90%
# Count                                    43
# Unique                                    1
#
# [3 rows x 133 columns]

# %%
# also looking at count and unique to help with deciding which columns to keep

with pd.option_context('display.max_rows', 150):
    display(df_isna.T.sort_values(by=['Count','Unique','Null'], ascending=True))
# Out:
#                                                        Null  Count Unique
# last_sale                                           100.00%      0      0
# top_bid                                             100.00%      0      0
# listing_date                                        100.00%      0      0
# transfer_fee_payment_token                          100.00%      0      0
# owner.user                                          100.00%      0      0
# creator.user                                        100.00%      0      0
# creator                                             100.00%      0      0
# last_sale.asset_bundle                              100.00%      0      0
# last_sale.transaction.to_account.discord_id         100.00%      0      0
# last_sale.transaction.from_account.user             100.00%      0      0
# last_sale.transaction.to_account.user               100.00%      0      0
# collection.short_description                         99.91%     40      5
# transfer_fee_payment_token.id                        99.90%     43      1
# transfer_fee_payment_token.symbol                    99.90%     43      1
# transfer_fee_payment_token.address                   99.90%     43      1
# transfer_fee_payment_token.image_url                 99.90%     43      1
# transfer_fee_payment_token.name                      99.90%     43      1
# transfer_fee_payment_token.decimals                  99.90%     43      1
# transfer_fee_payment_token.eth_price                 99.90%     43      1
# transfer_fee_payment_token.usd_price                 99.90%     43      1
# transfer_fee                                         99.90%     43      9
# owner.discord_id                                     99.89%     51      8
# last_sale.transaction.from_account.discord_id        99.85%     67     32
# creator.discord_id                                   99.49%    229     45
# collection.chat_url                                  97.89%    946      1
# last_sale.transaction.from_account.config            97.81%    978      4
# creator.config                                       96.27%   1669      4
# last_sale.asset.decimals                             94.99%   2244      1
# animation_url                                        94.03%   2673   2231
# animation_original_url                               94.00%   2684   2243
# collection.medium_username                           92.07%   3551    143
# asset_contract.payout_address                        90.76%   4134    129
# owner.config                                         89.35%   4768      4
# collection.telegram_url                              89.06%   4896    198
# decimals                                             88.87%   4981      1
# collection.instagram_username                        88.47%   5158    567
# collection.display_data.images                       85.52%   6482     26
# token_metadata                                       84.70%   6847   6791
# last_sale.transaction.from_account.user.username     82.62%   7776   4240
# collection.wiki_url                                  78.02%   9837      2
# last_sale.auction_type                               77.85%   9911      1
# sell_orders                                          77.54%  10052  10052
# asset_contract.opensea_version                       71.42%  12791      3
# asset_contract.total_supply                          70.45%  13225     21
# last_sale.transaction.to_account.config              69.72%  13550      2
# last_sale.transaction.to_account.user.username       69.64%  13587     19
# collection.payout_address                            69.30%  13740   1525
# last_sale.quantity                                   67.15%  14701     52
# last_sale.payment_token.eth_price                    64.90%  15710     21
# last_sale.payment_token.usd_price                    64.90%  15710     22
# last_sale.event_type                                 64.89%  15713      1
# last_sale.payment_token.decimals                     64.89%  15713      6
# last_sale.payment_token.id                           64.89%  15713     26
# last_sale.payment_token.symbol                       64.89%  15713     26
# last_sale.payment_token.address                      64.89%  15713     26
# last_sale.payment_token.image_url                    64.89%  15713     26
# last_sale.payment_token.name                         64.89%  15713     26
# last_sale.transaction.to_account.profile_img_url     64.89%  15713     27
# last_sale.transaction.from_account.profile_img_url   64.89%  15713     33
# last_sale.transaction.to_account.address             64.89%  15713     62
# last_sale.transaction.transaction_index              64.89%  15713    373
# last_sale.total_price                                64.89%  15713   5784
# last_sale.transaction.from_account.address           64.89%  15713   8635
# last_sale.created_date                               64.89%  15713   9359
# last_sale.transaction.block_number                   64.89%  15713  14269
# last_sale.event_timestamp                            64.89%  15713  14270
# last_sale.transaction.timestamp                      64.89%  15713  14270
# last_sale.transaction.block_hash                     64.89%  15713  14271
# last_sale.transaction.id                             64.89%  15713  15679
# last_sale.transaction.transaction_hash               64.89%  15713  15679
# last_sale.asset.token_id                             64.89%  15713  15713
# external_link                                        59.36%  18185  15485
# creator.user.username                                54.31%  20449   4266
# background_color                                     52.59%  21219     48
# image_original_url                                   40.96%  26420  25526
# collection.discord_url                               39.94%  26876    357
# asset_contract.description                           39.89%  26900    221
# asset_contract.external_link                         39.50%  27073    215
# asset_contract.image_url                             39.29%  27170    223
# owner.user.username                                  37.88%  27800   2803
# asset_contract.nft_version                           32.93%  30017      3
# collection.featured_image_url                        28.90%  31817   1355
# collection.external_url                              27.51%  32440   1064
# asset_contract.symbol                                26.89%  32716    231
# collection.twitter_username                          25.47%  33352   1199
# collection.large_image_url                           24.65%  33722   1404
# description                                          24.60%  33741  18946
# name                                                 19.40%  36072  33675
# collection.banner_image_url                          18.99%  36254   1583
# asset_contract.owner                                 13.35%  38778    191
# collection.description                               12.19%  39295   2494
# collection.image_url                                 10.77%  39934   2735
# collection.display_data.card_display_style           10.73%  39951      3
# image_preview_url                                    10.55%  40031  28811
# image_thumbnail_url                                  10.55%  40031  28811
# image_url                                            10.55%  40031  28813
# creator.profile_img_url                               0.79%  44398     33
# creator.address                                       0.79%  44398   5466
# asset_contract.dev_buyer_fee_basis_points             0.00%  44752      1
# asset_contract.only_proxied_transfers                 0.00%  44752      1
# asset_contract.opensea_buyer_fee_basis_points         0.00%  44752      1
# asset_contract.buyer_fee_basis_points                 0.00%  44752      1
# collection.dev_buyer_fee_basis_points                 0.00%  44752      1
# collection.is_subject_to_whitelist                    0.00%  44752      1
# collection.only_proxied_transfers                     0.00%  44752      1
# collection.opensea_buyer_fee_basis_points             0.00%  44752      1
# is_presale                                            0.00%  44752      2
# asset_contract.asset_contract_type                    0.00%  44752      2
# asset_contract.default_to_fiat                        0.00%  44752      2
# asset_contract.opensea_seller_fee_basis_points        0.00%  44752      2
# collection.default_to_fiat                            0.00%  44752      2
# collection.featured                                   0.00%  44752      2
# collection.hidden                                     0.00%  44752      2
# collection.opensea_seller_fee_basis_points            0.00%  44752      2
# collection.require_email                              0.00%  44752      2
# asset_contract.schema_name                            0.00%  44752      3
# collection.safelist_request_status                    0.00%  44752      4
# asset_contract.dev_seller_fee_basis_points            0.00%  44752     14
# asset_contract.seller_fee_basis_points                0.00%  44752     14
# owner.profile_img_url                                 0.00%  44752     33
# collection.dev_seller_fee_basis_points                0.00%  44752     50
# num_sales                                             0.00%  44752    202
# asset_contract.name                                   0.00%  44752    268
# asset_contract.created_date                           0.00%  44752    292
# asset_contract.address                                0.00%  44752    294
# collection.created_date                               0.00%  44752   2785
# collection.slug                                       0.00%  44752   2791
# collection.name                                       0.00%  44752   2793
# owner.address                                         0.00%  44752  11452
# traits                                                0.00%  44752  19849
# id                                                    0.00%  44752  44752
# token_id                                              0.00%  44752  44752
# permalink                                             0.00%  44752  44752

# %%
# selecting target columns and desired predictors

df = df_full[[
    # target
    'num_sales', 'sell_orders', 'last_sale.event_type', 
    
    # basic attributes    
    'id', 'token_id', 'name', 'traits', 'description', 'is_presale', 
    'image_url', 'background_color', 'external_link', 'token_metadata',
    
    # asset attributes
    'asset_contract.created_date', 'asset_contract.name', 'asset_contract.description', 'asset_contract.total_supply',
    'asset_contract.symbol', 'asset_contract.schema_name', 'asset_contract.asset_contract_type', 
    'asset_contract.nft_version', 'asset_contract.opensea_version',
    'asset_contract.seller_fee_basis_points', 'asset_contract.dev_seller_fee_basis_points',
    'asset_contract.opensea_seller_fee_basis_points',
    'asset_contract.external_link', 'asset_contract.image_url', 
    
    # collection attributes
    'collection.created_date', 'collection.slug', 'collection.safelist_request_status', 'collection.featured', 
    'collection.description', 'collection.display_data.card_display_style',
    'collection.dev_seller_fee_basis_points', 'collection.opensea_seller_fee_basis_points',
    'collection.external_url', 'collection.image_url', 'collection.large_image_url', 'collection.display_data.images', 
    'collection.twitter_username', 'collection.instagram_username', 'collection.discord_url', 
    'collection.telegram_url', 'collection.medium_username', 'collection.chat_url', 
    
    # creator attributes
    'creator.user.username', 'creator.config', 'creator.profile_img_url', 'creator.discord_id',
    
    # owner attributes
    'owner.address', 'owner.config', 'owner.profile_img_url', 'owner.discord_id' 
    ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44752 entries, 0 to 44751
# Data columns (total 53 columns):
# num_sales                                         44752 non-null int64
# sell_orders                                       10052 non-null object
# last_sale.event_type                              15713 non-null object
# id                                                44752 non-null int64
# token_id                                          44752 non-null object
# name                                              36072 non-null object
# traits                                            44752 non-null object
# description                                       33741 non-null object
# is_presale                                        44752 non-null bool
# image_url                                         40031 non-null object
# background_color                                  21219 non-null object
# external_link                                     18185 non-null object
# token_metadata                                    6847 non-null object
# asset_contract.created_date                       44752 non-null datetime64[ns]
# asset_contract.name                               44752 non-null object
# asset_contract.description                        26900 non-null object
# asset_contract.total_supply                       13225 non-null object
# asset_contract.symbol                             32716 non-null object
# asset_contract.schema_name                        44752 non-null object
# asset_contract.asset_contract_type                44752 non-null object
# asset_contract.nft_version                        30017 non-null object
# asset_contract.opensea_version                    12791 non-null object
# asset_contract.seller_fee_basis_points            44752 non-null int64
# asset_contract.dev_seller_fee_basis_points        44752 non-null int64
# asset_contract.opensea_seller_fee_basis_points    44752 non-null int64
# asset_contract.external_link                      27073 non-null object
# asset_contract.image_url                          27170 non-null object
# collection.created_date                           44752 non-null datetime64[ns]
# collection.slug                                   44752 non-null object
# collection.safelist_request_status                44752 non-null object
# collection.featured                               44752 non-null bool
# collection.description                            39295 non-null object
# collection.display_data.card_display_style        39951 non-null object
# collection.dev_seller_fee_basis_points            44752 non-null int64
# collection.opensea_seller_fee_basis_points        44752 non-null int64
# collection.external_url                           32440 non-null object
# collection.image_url                              39934 non-null object
# collection.large_image_url                        33722 non-null object
# collection.display_data.images                    6482 non-null object
# collection.twitter_username                       33352 non-null object
# collection.instagram_username                     5158 non-null object
# collection.discord_url                            26876 non-null object
# collection.telegram_url                           4896 non-null object
# collection.medium_username                        3551 non-null object
# collection.chat_url                               946 non-null object
# creator.user.username                             20449 non-null object
# creator.config                                    1669 non-null object
# creator.profile_img_url                           44398 non-null object
# creator.discord_id                                229 non-null object
# owner.address                                     44752 non-null object
# owner.config                                      4768 non-null object
# owner.profile_img_url                             44752 non-null object
# owner.discord_id                                  51 non-null object
# dtypes: bool(2), datetime64[ns](2), int64(7), object(42)
# memory usage: 17.5+ MB

# %% [markdown]
# ### Exploration

# %% [markdown]
# #### Explore Targets

# %%
with pd.option_context('display.max_columns', 60):
    display(df.head())a
# Out:
#    num_sales sell_orders last_sale.event_type        id  \
# 0          0         NaN                  NaN  30033345
# 1          0         NaN                  NaN  30033344
# 2          0         NaN                  NaN  30033343
# 3          0         NaN                  NaN  30033342
# 4          0         NaN                  NaN  30033341
#
#                                             token_id  \
# 0  9132198125583360689797322472203169750011716430...
# 1  3268304683559065074852929730958675774624902165...
# 2  7779220728716121010175700030620486582973273824...
# 3  9510190511962339173712504282354773321324120343...
# 4  1029511648543007736247727748847500291464805430...
#
#                        name  \
# 0             Chad Olozumin
# 1  IconPunk #149 Elton John
# 2         PlagueDoctor #234
# 3    Crypto Graphic #47/999
# 4                       380
#
#                                               traits  \
# 0                                                 []
# 1  [{'trait_type': 'id', 'value': '0149', 'displa...
# 2  [{'trait_type': 'id', 'value': '234', 'display...
# 3                                                 []
# 4  [{'trait_type': 'Clothes', 'value': 'Tanktop',...
#
#                                          description  is_presale  \
# 0                                                NaN        True
# 1  24x24 pixels and pushing the limit to the max!...        True
# 2  Where are the sick - There I Am. Healing since...        True
# 3  #crypto #abstract #art #collectible #rarible #...        True
# 4                                                NaN        True
#
#                                            image_url background_color  \
# 0  https://storage.opensea.io/files/b09d044f17573...              NaN
# 1  https://lh3.googleusercontent.com/P7NXQatzHWTt...              NaN
# 2  https://lh3.googleusercontent.com/qCzcK3sEGp2R...              NaN
# 3  https://lh3.googleusercontent.com/iDHrRY_ko62L...              NaN
# 4  https://lh3.googleusercontent.com/LrBXq8LND7W-...              NaN
#
#                                        external_link token_metadata  \
# 0  https://cryptohamsters.co/hamsters/16250054780...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   asset_contract.created_date asset_contract.name asset_contract.description  \
# 0  2020-12-02 17:40:53.232025  OpenSea Collection                        NaN
# 1  2020-12-02 17:40:53.232025  OpenSea Collection                        NaN
# 2  2020-12-02 17:40:53.232025  OpenSea Collection                        NaN
# 3  2020-12-02 17:40:53.232025  OpenSea Collection                        NaN
# 4  2020-12-02 17:40:53.232025  OpenSea Collection                        NaN
#
#   asset_contract.total_supply asset_contract.symbol  \
# 0                         NaN             OPENSTORE
# 1                         NaN             OPENSTORE
# 2                         NaN             OPENSTORE
# 3                         NaN             OPENSTORE
# 4                         NaN             OPENSTORE
#
#   asset_contract.schema_name asset_contract.asset_contract_type  \
# 0                    ERC1155                      semi-fungible
# 1                    ERC1155                      semi-fungible
# 2                    ERC1155                      semi-fungible
# 3                    ERC1155                      semi-fungible
# 4                    ERC1155                      semi-fungible
#
#   asset_contract.nft_version asset_contract.opensea_version  \
# 0                        NaN                          2.0.0
# 1                        NaN                          2.0.0
# 2                        NaN                          2.0.0
# 3                        NaN                          2.0.0
# 4                        NaN                          2.0.0
#
#    asset_contract.seller_fee_basis_points  \
# 0                                     250
# 1                                     250
# 2                                     250
# 3                                     250
# 4                                     250
#
#    asset_contract.dev_seller_fee_basis_points  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    asset_contract.opensea_seller_fee_basis_points  \
# 0                                             250
# 1                                             250
# 2                                             250
# 3                                             250
# 4                                             250
#
#   asset_contract.external_link asset_contract.image_url  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
#
#      collection.created_date         collection.slug  \
# 0 2021-06-10 01:49:35.180218  cryptohamstersofficial
# 1 2021-05-03 18:55:32.762585               iconpunks
# 2 2021-05-19 07:24:46.125544          plaguedoctor-1
# 3 2021-06-29 12:49:00.283468          crypto-graphic
# 4 2021-05-30 16:45:39.254227      boredalienmarsclub
#
#   collection.safelist_request_status  collection.featured  \
# 0                      not_requested                False
# 1                      not_requested                False
# 2                      not_requested                False
# 3                      not_requested                False
# 4                      not_requested                False
#
#                               collection.description  \
# 0  CryptoHamsters are composed of DNA with 18 gen...
# 1  24x24 pixels and pushing the limit to the max!...
# 2  Where are the sick - There I Am. Healing since...
# 3  Crypto Graphic plan to mint 999 nos. exclusive...
# 4  The Bored Alien Mars Club is a collection of 1...
#
#   collection.display_data.card_display_style  \
# 0                                    contain
# 1                                     padded
# 2                                     padded
# 3                                    contain
# 4                                    contain
#
#    collection.dev_seller_fee_basis_points  \
# 0                                     300
# 1                                     500
# 2                                       0
# 3                                       0
# 4                                    1000
#
#    collection.opensea_seller_fee_basis_points  \
# 0                                         250
# 1                                         250
# 2                                         250
# 3                                         250
# 4                                         250
#
#                collection.external_url  \
# 0            https://cryptohamsters.co
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4  http://www.BoredAlienMarsClub.space
#
#                                 collection.image_url  \
# 0  https://lh3.googleusercontent.com/0GER9b0kES2j...
# 1  https://lh3.googleusercontent.com/2dVGNcqjWQCX...
# 2  https://lh3.googleusercontent.com/ajZlyodqeIqG...
# 3  https://lh3.googleusercontent.com/M10iGqR6S42O...
# 4  https://lh3.googleusercontent.com/dcYlehz5K9NJ...
#
#                           collection.large_image_url  \
# 0  https://lh3.googleusercontent.com/19DfEbcwtSrf...
# 1  https://lh3.googleusercontent.com/Y0XW9uG7RyV1...
# 2                                                NaN
# 3  https://lh3.googleusercontent.com/yWUmuEpQaT35...
# 4                                                NaN
#
#   collection.display_data.images collection.twitter_username  \
# 0                            NaN             cryptohamsters_
# 1                            NaN                    NFTPUNKS
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                BoredAlienMC
#
#   collection.instagram_username         collection.discord_url  \
# 0                cryptohamsters  https://discord.gg/pXD8MnbeBQ
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN  https://discord.gg/A9zr2H9GjQ
#
#   collection.telegram_url collection.medium_username collection.chat_url  \
# 0                     NaN                        NaN                 NaN
# 1                     NaN                        NaN                 NaN
# 2                     NaN                        NaN                 NaN
# 3                     NaN                        NaN                 NaN
# 4                     NaN                        NaN                 NaN
#
#     creator.user.username creator.config  \
# 0  CryptoHamstersOfficial            NaN
# 1               iconpunks            NaN
# 2                PlagueDr            NaN
# 3           Vezzen_Dragon            NaN
# 4              BoredAlien            NaN
#
#                              creator.profile_img_url creator.discord_id  \
# 0  https://storage.googleapis.com/opensea-static/...                NaN
# 1  https://storage.googleapis.com/opensea-static/...                NaN
# 2  https://storage.googleapis.com/opensea-static/...                NaN
# 3  https://storage.googleapis.com/opensea-static/...                NaN
# 4  https://storage.googleapis.com/opensea-static/...                NaN
#
#                                 owner.address owner.config  \
# 0  0x0000000000000000000000000000000000000000          NaN
# 1  0x0000000000000000000000000000000000000000          NaN
# 2  0x0000000000000000000000000000000000000000          NaN
# 3  0x0000000000000000000000000000000000000000          NaN
# 4  0x0000000000000000000000000000000000000000          NaN
#
#                                owner.profile_img_url owner.discord_id
# 0  https://storage.googleapis.com/opensea-static/...              NaN
# 1  https://storage.googleapis.com/opensea-static/...              NaN
# 2  https://storage.googleapis.com/opensea-static/...              NaN
# 3  https://storage.googleapis.com/opensea-static/...              NaN
# 4  https://storage.googleapis.com/opensea-static/...              NaN

# %%
df['sell_orders'].isna().value_counts()
# Out:
# True     34700
# False    10052
# Name: sell_orders, dtype: int64

# %%
df['num_sales'].value_counts().plot()

# %%
with pd.option_context('display.max_columns', 60):
    display(df['num_sales'][df['asset_contract.name'] == 'Dodgers MLB Crypto'])
# Out:
# 39477    15
# 39478    15
# 39479    15
# 39480    15
# 39481    15
#          ..
# 43614    15
# 43615    15
# 43616    15
# 43617    15
# 43618    15
# Name: num_sales, Length: 4038, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-9ccf03e3243b> in <module>()
#       1 with pd.option_context('display.max_columns', 60):
# ----> 2     display(df['num_sales'][df['asset_contract.name'] == 'Dodgers MLB Crypto']).value_counts()
#
# AttributeError: 'NoneType' object has no attribute 'value_counts'

# %% [markdown]
# ### Final Output
# - First three columns are target
# - Needs further preprocessing

# %%
df.to_csv('../data/2_data_condensed.csv', index=False)
