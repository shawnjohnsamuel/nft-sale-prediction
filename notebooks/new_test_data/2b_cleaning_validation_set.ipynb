# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ### Data

# %%
#import just ids of original data set on which model was built
df_original = pd.read_csv('../data/1_data_initial.csv', usecols=['id'])

# %%
#import the full validation set
parse_dates = ['listing_date', 
               'asset_contract.created_date', 
               'collection.created_date', 
               'last_sale.created_date']
df_full = pd.read_csv('../data/1b_data_initial_validation_set.csv', low_memory=False, parse_dates=parse_dates)

# %%
# create a list of all unique ids in the validation set that are not present in the original set
df_orig_ids = df_original['id']
df_full_ids = df_full['id']
new_unique_ids = [x for x in df_full_ids if x not in df_orig_ids]

# %%
len(new_unique_ids)
# Out:
# 26241

# %%
# create new dataframe of unique NFTs
df_full = df_full[df_full['id'].isin(new_unique_ids)]

# %%
df_full.head()
# Out:
#          id                                           token_id  num_sales  \
# 0  31278619  6715461703434003445645336638579260494260736795...          0
# 1  31278618  3108049546517070910075436470153648977290720661...          0
# 2  31278617  9057683344706687937980539802150068508547322538...          0
# 3  31278616  3268304683559065074852929730958675774624902165...          0
# 4  31278614  7779220728716121010175700030620486582973273824...          0
#
#   background_color                                          image_url  \
# 0              NaN  https://lh3.googleusercontent.com/Pd7PXs5ZHtgv...
# 1              NaN  https://lh3.googleusercontent.com/KfteuZFSCiCO...
# 2              NaN  https://lh3.googleusercontent.com/caAUHZLbhExp...
# 3              NaN  https://lh3.googleusercontent.com/4XUpEHLMNbJl...
# 4              NaN  https://lh3.googleusercontent.com/pcJ0zq1Gr-ND...
#
#                                    image_preview_url  \
# 0  https://lh3.googleusercontent.com/Pd7PXs5ZHtgv...
# 1  https://lh3.googleusercontent.com/KfteuZFSCiCO...
# 2  https://lh3.googleusercontent.com/caAUHZLbhExp...
# 3  https://lh3.googleusercontent.com/4XUpEHLMNbJl...
# 4  https://lh3.googleusercontent.com/pcJ0zq1Gr-ND...
#
#                                  image_thumbnail_url image_original_url  \
# 0  https://lh3.googleusercontent.com/Pd7PXs5ZHtgv...                NaN
# 1  https://lh3.googleusercontent.com/KfteuZFSCiCO...                NaN
# 2  https://lh3.googleusercontent.com/caAUHZLbhExp...                NaN
# 3  https://lh3.googleusercontent.com/4XUpEHLMNbJl...                NaN
# 4  https://lh3.googleusercontent.com/pcJ0zq1Gr-ND...                NaN
#
#   animation_url animation_original_url  ...  \
# 0           NaN                    NaN  ...
# 1           NaN                    NaN  ...
# 2           NaN                    NaN  ...
# 3           NaN                    NaN  ...
# 4           NaN                    NaN  ...
#
#   last_sale.transaction.to_account.user  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   last_sale.transaction.from_account.user transfer_fee_payment_token.id  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
#
#   transfer_fee_payment_token.symbol  transfer_fee_payment_token.address  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   transfer_fee_payment_token.image_url transfer_fee_payment_token.name  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#   transfer_fee_payment_token.decimals  transfer_fee_payment_token.eth_price  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#    transfer_fee_payment_token.usd_price
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 133 columns]

# %%
df_full.id.nunique()
# Out:
# 26241

# %%
df_full.token_id.nunique()
# Out:
# 26241

# %%
list(df_full.columns)
# Out:
# ['id',
#  'token_id',
#  'num_sales',
#  'background_color',
#  'image_url',
#  'image_preview_url',
#  'image_thumbnail_url',
#  'image_original_url',
#  'animation_url',
#  'animation_original_url',
#  'name',
#  'description',
#  'external_link',
#  'permalink',
#  'decimals',
#  'token_metadata',
#  'sell_orders',
#  'traits',
#  'last_sale',
#  'top_bid',
#  'listing_date',
#  'is_presale',
#  'transfer_fee_payment_token',
#  'transfer_fee',
#  'asset_contract.address',
#  'asset_contract.asset_contract_type',
#  'asset_contract.created_date',
#  'asset_contract.name',
#  'asset_contract.nft_version',
#  'asset_contract.opensea_version',
#  'asset_contract.owner',
#  'asset_contract.schema_name',
#  'asset_contract.symbol',
#  'asset_contract.total_supply',
#  'asset_contract.description',
#  'asset_contract.external_link',
#  'asset_contract.image_url',
#  'asset_contract.default_to_fiat',
#  'asset_contract.dev_buyer_fee_basis_points',
#  'asset_contract.dev_seller_fee_basis_points',
#  'asset_contract.only_proxied_transfers',
#  'asset_contract.opensea_buyer_fee_basis_points',
#  'asset_contract.opensea_seller_fee_basis_points',
#  'asset_contract.buyer_fee_basis_points',
#  'asset_contract.seller_fee_basis_points',
#  'asset_contract.payout_address',
#  'collection.banner_image_url',
#  'collection.chat_url',
#  'collection.created_date',
#  'collection.default_to_fiat',
#  'collection.description',
#  'collection.dev_buyer_fee_basis_points',
#  'collection.dev_seller_fee_basis_points',
#  'collection.discord_url',
#  'collection.display_data.card_display_style',
#  'collection.external_url',
#  'collection.featured',
#  'collection.featured_image_url',
#  'collection.hidden',
#  'collection.safelist_request_status',
#  'collection.image_url',
#  'collection.is_subject_to_whitelist',
#  'collection.large_image_url',
#  'collection.medium_username',
#  'collection.name',
#  'collection.only_proxied_transfers',
#  'collection.opensea_buyer_fee_basis_points',
#  'collection.opensea_seller_fee_basis_points',
#  'collection.payout_address',
#  'collection.require_email',
#  'collection.short_description',
#  'collection.slug',
#  'collection.telegram_url',
#  'collection.twitter_username',
#  'collection.instagram_username',
#  'collection.wiki_url',
#  'owner.user.username',
#  'owner.profile_img_url',
#  'owner.address',
#  'owner.config',
#  'owner.discord_id',
#  'creator.user.username',
#  'creator.profile_img_url',
#  'creator.address',
#  'creator.config',
#  'creator.discord_id',
#  'collection.display_data.images',
#  'creator.user',
#  'owner.user',
#  'creator',
#  'last_sale.asset.token_id',
#  'last_sale.asset.decimals',
#  'last_sale.asset_bundle',
#  'last_sale.event_type',
#  'last_sale.event_timestamp',
#  'last_sale.auction_type',
#  'last_sale.total_price',
#  'last_sale.payment_token.id',
#  'last_sale.payment_token.symbol',
#  'last_sale.payment_token.address',
#  'last_sale.payment_token.image_url',
#  'last_sale.payment_token.name',
#  'last_sale.payment_token.decimals',
#  'last_sale.payment_token.eth_price',
#  'last_sale.payment_token.usd_price',
#  'last_sale.transaction.block_hash',
#  'last_sale.transaction.block_number',
#  'last_sale.transaction.from_account.user.username',
#  'last_sale.transaction.from_account.profile_img_url',
#  'last_sale.transaction.from_account.address',
#  'last_sale.transaction.from_account.config',
#  'last_sale.transaction.from_account.discord_id',
#  'last_sale.transaction.id',
#  'last_sale.transaction.timestamp',
#  'last_sale.transaction.to_account.user.username',
#  'last_sale.transaction.to_account.profile_img_url',
#  'last_sale.transaction.to_account.address',
#  'last_sale.transaction.to_account.config',
#  'last_sale.transaction.to_account.discord_id',
#  'last_sale.transaction.transaction_hash',
#  'last_sale.transaction.transaction_index',
#  'last_sale.created_date',
#  'last_sale.quantity',
#  'last_sale.transaction.to_account.user',
#  'last_sale.transaction.from_account.user',
#  'transfer_fee_payment_token.id',
#  'transfer_fee_payment_token.symbol',
#  'transfer_fee_payment_token.address',
#  'transfer_fee_payment_token.image_url',
#  'transfer_fee_payment_token.name',
#  'transfer_fee_payment_token.decimals',
#  'transfer_fee_payment_token.eth_price',
#  'transfer_fee_payment_token.usd_price']

# %%
# checking for percentage of null values

for column in list(df_full.columns):
    print(f"{df_full[str(column)].isna().sum()/len(df_full):.2%} of {column} is NAN")
# Out:
# 0.00% of id is NAN
# 0.00% of token_id is NAN
# 0.00% of num_sales is NAN
# 90.91% of background_color is NAN
# 20.49% of image_url is NAN
# 20.49% of image_preview_url is NAN
# 20.49% of image_thumbnail_url is NAN
# 62.40% of image_original_url is NAN
# 88.43% of animation_url is NAN
# 88.40% of animation_original_url is NAN
# 23.04% of name is NAN
# 32.29% of description is NAN
# 71.28% of external_link is NAN
# 0.00% of permalink is NAN
# 66.28% of decimals is NAN
# 61.19% of token_metadata is NAN
# 70.58% of sell_orders is NAN
# 0.00% of traits is NAN
# 100.00% of last_sale is NAN
# 100.00% of top_bid is NAN
# 100.00% of listing_date is NAN
# 0.00% of is_presale is NAN
# 100.00% of transfer_fee_payment_token is NAN
# 99.82% of transfer_fee is NAN
# 0.00% of asset_contract.address is NAN
# 0.00% of asset_contract.asset_contract_type is NAN
# 0.00% of asset_contract.created_date is NAN
# 0.00% of asset_contract.name is NAN
# 47.60% of asset_contract.nft_version is NAN
# 60.00% of asset_contract.opensea_version is NAN
# 27.19% of asset_contract.owner is NAN
# 0.00% of asset_contract.schema_name is NAN
# 9.54% of asset_contract.symbol is NAN
# 78.41% of asset_contract.total_supply is NAN
# 59.12% of asset_contract.description is NAN
# 58.42% of asset_contract.external_link is NAN
# 57.52% of asset_contract.image_url is NAN
# 0.00% of asset_contract.default_to_fiat is NAN
# 0.00% of asset_contract.dev_buyer_fee_basis_points is NAN
# 0.00% of asset_contract.dev_seller_fee_basis_points is NAN
# 0.00% of asset_contract.only_proxied_transfers is NAN
# 0.00% of asset_contract.opensea_buyer_fee_basis_points is NAN
# 0.00% of asset_contract.opensea_seller_fee_basis_points is NAN
# 0.00% of asset_contract.buyer_fee_basis_points is NAN
# 0.00% of asset_contract.seller_fee_basis_points is NAN
# 74.16% of asset_contract.payout_address is NAN
# 30.22% of collection.banner_image_url is NAN
# 95.08% of collection.chat_url is NAN
# 0.00% of collection.created_date is NAN
# 0.00% of collection.default_to_fiat is NAN
# 20.98% of collection.description is NAN
# 0.00% of collection.dev_buyer_fee_basis_points is NAN
# 0.00% of collection.dev_seller_fee_basis_points is NAN
# 63.80% of collection.discord_url is NAN
# 16.09% of collection.display_data.card_display_style is NAN
# 45.72% of collection.external_url is NAN
# 0.00% of collection.featured is NAN
# 42.38% of collection.featured_image_url is NAN
# 0.00% of collection.hidden is NAN
# 0.00% of collection.safelist_request_status is NAN
# 17.56% of collection.image_url is NAN
# 0.00% of collection.is_subject_to_whitelist is NAN
# 35.18% of collection.large_image_url is NAN
# 84.61% of collection.medium_username is NAN
# 0.00% of collection.name is NAN
# 0.00% of collection.only_proxied_transfers is NAN
# 0.00% of collection.opensea_buyer_fee_basis_points is NAN
# 0.00% of collection.opensea_seller_fee_basis_points is NAN
# 43.16% of collection.payout_address is NAN
# 0.00% of collection.require_email is NAN
# 99.86% of collection.short_description is NAN
# 0.00% of collection.slug is NAN
# 75.19% of collection.telegram_url is NAN
# 42.71% of collection.twitter_username is NAN
# 75.54% of collection.instagram_username is NAN
# 99.72% of collection.wiki_url is NAN
# 29.96% of owner.user.username is NAN
# 0.00% of owner.profile_img_url is NAN
# 0.00% of owner.address is NAN
# 96.98% of owner.config is NAN
# 99.93% of owner.discord_id is NAN
# 30.97% of creator.user.username is NAN
# 1.07% of creator.profile_img_url is NAN
# 1.07% of creator.address is NAN
# 94.44% of creator.config is NAN
# 99.25% of creator.discord_id is NAN
# 78.15% of collection.display_data.images is NAN
# 100.00% of creator.user is NAN
# 100.00% of owner.user is NAN
# 100.00% of creator is NAN
# 73.63% of last_sale.asset.token_id is NAN
# 91.28% of last_sale.asset.decimals is NAN
# 100.00% of last_sale.asset_bundle is NAN
# 73.63% of last_sale.event_type is NAN
# 73.63% of last_sale.event_timestamp is NAN
# 94.83% of last_sale.auction_type is NAN
# 73.63% of last_sale.total_price is NAN
# 73.63% of last_sale.payment_token.id is NAN
# 73.63% of last_sale.payment_token.symbol is NAN
# 73.63% of last_sale.payment_token.address is NAN
# 73.63% of last_sale.payment_token.image_url is NAN
# 73.63% of last_sale.payment_token.name is NAN
# 73.63% of last_sale.payment_token.decimals is NAN
# 73.64% of last_sale.payment_token.eth_price is NAN
# 73.64% of last_sale.payment_token.usd_price is NAN
# 73.63% of last_sale.transaction.block_hash is NAN
# 73.63% of last_sale.transaction.block_number is NAN
# 78.94% of last_sale.transaction.from_account.user.username is NAN
# 73.63% of last_sale.transaction.from_account.profile_img_url is NAN
# 73.63% of last_sale.transaction.from_account.address is NAN
# 98.29% of last_sale.transaction.from_account.config is NAN
# 99.81% of last_sale.transaction.from_account.discord_id is NAN
# 73.63% of last_sale.transaction.id is NAN
# 73.63% of last_sale.transaction.timestamp is NAN
# 79.03% of last_sale.transaction.to_account.user.username is NAN
# 73.63% of last_sale.transaction.to_account.profile_img_url is NAN
# 73.63% of last_sale.transaction.to_account.address is NAN
# 79.04% of last_sale.transaction.to_account.config is NAN
# 100.00% of last_sale.transaction.to_account.discord_id is NAN
# 73.63% of last_sale.transaction.transaction_hash is NAN
# 73.63% of last_sale.transaction.transaction_index is NAN
# 73.63% of last_sale.created_date is NAN
# 73.89% of last_sale.quantity is NAN
# 100.00% of last_sale.transaction.to_account.user is NAN
# 100.00% of last_sale.transaction.from_account.user is NAN
# 99.82% of transfer_fee_payment_token.id is NAN
# 99.82% of transfer_fee_payment_token.symbol is NAN
# 99.82% of transfer_fee_payment_token.address is NAN
# 99.82% of transfer_fee_payment_token.image_url is NAN
# 99.82% of transfer_fee_payment_token.name is NAN
# 99.82% of transfer_fee_payment_token.decimals is NAN
# 99.82% of transfer_fee_payment_token.eth_price is NAN
# 99.82% of transfer_fee_payment_token.usd_price is NAN

# %%
df_isna = pd.DataFrame()

for column in df_full.columns:
    df_isna.loc['Null', column] = f"{df_full[column].isna().sum()/len(df_full):.2%}"
    df_isna.loc['Count', column] = df_full[column].count()
    df_isna.loc['Unique', column] = df_full[column].nunique()

# %%
df_isna
# Out:
#            id token_id num_sales background_color image_url image_preview_url  \
# Null    0.00%    0.00%     0.00%           90.91%    20.49%            20.49%
# Count   26241    26241     26241             2384     20864             20864
# Unique  26241    26241       206               41     18189             18189
#
#        image_thumbnail_url image_original_url animation_url  \
# Null                20.49%             62.40%        88.43%
# Count                20864               9866          3037
# Unique               18189               8557          2312
#
#        animation_original_url  ... last_sale.transaction.to_account.user  \
# Null                   88.40%  ...                               100.00%
# Count                    3045  ...                                     0
# Unique                   2322  ...                                     0
#
#        last_sale.transaction.from_account.user transfer_fee_payment_token.id  \
# Null                                   100.00%                        99.82%
# Count                                        0                            47
# Unique                                       0                             1
#
#        transfer_fee_payment_token.symbol transfer_fee_payment_token.address  \
# Null                              99.82%                             99.82%
# Count                                 47                                 47
# Unique                                 1                                  1
#
#        transfer_fee_payment_token.image_url transfer_fee_payment_token.name  \
# Null                                 99.82%                          99.82%
# Count                                    47                              47
# Unique                                    1                               1
#
#        transfer_fee_payment_token.decimals  \
# Null                                99.82%
# Count                                   47
# Unique                                   1
#
#        transfer_fee_payment_token.eth_price  \
# Null                                 99.82%
# Count                                    47
# Unique                                    1
#
#        transfer_fee_payment_token.usd_price
# Null                                 99.82%
# Count                                    47
# Unique                                    1
#
# [3 rows x 133 columns]

# %%
# also looking at count and unique to help with deciding which columns to keep

with pd.option_context('display.max_rows', 150):
    display(df_isna.T.sort_values(by=['Count','Unique','Null'], ascending=True))
# Out:
#                                                        Null  Count Unique
# last_sale                                           100.00%      0      0
# top_bid                                             100.00%      0      0
# listing_date                                        100.00%      0      0
# transfer_fee_payment_token                          100.00%      0      0
# creator.user                                        100.00%      0      0
# owner.user                                          100.00%      0      0
# creator                                             100.00%      0      0
# last_sale.asset_bundle                              100.00%      0      0
# last_sale.transaction.to_account.discord_id         100.00%      0      0
# last_sale.transaction.to_account.user               100.00%      0      0
# last_sale.transaction.from_account.user             100.00%      0      0
# owner.discord_id                                     99.93%     19      8
# collection.short_description                         99.86%     36      3
# transfer_fee_payment_token.id                        99.82%     47      1
# transfer_fee_payment_token.symbol                    99.82%     47      1
# transfer_fee_payment_token.address                   99.82%     47      1
# transfer_fee_payment_token.image_url                 99.82%     47      1
# transfer_fee_payment_token.name                      99.82%     47      1
# transfer_fee_payment_token.decimals                  99.82%     47      1
# transfer_fee_payment_token.eth_price                 99.82%     47      1
# transfer_fee_payment_token.usd_price                 99.82%     47      1
# transfer_fee                                         99.82%     47      9
# last_sale.transaction.from_account.discord_id        99.81%     51     23
# collection.wiki_url                                  99.72%     73      2
# creator.discord_id                                   99.25%    196     44
# last_sale.transaction.from_account.config            98.29%    449      4
# owner.config                                         96.98%    793      4
# collection.chat_url                                  95.08%   1292      1
# last_sale.auction_type                               94.83%   1356      1
# creator.config                                       94.44%   1459      4
# last_sale.asset.decimals                             91.28%   2289      1
# background_color                                     90.91%   2384     41
# animation_url                                        88.43%   3037   2312
# animation_original_url                               88.40%   3045   2322
# collection.medium_username                           84.61%   4039    140
# last_sale.transaction.to_account.config              79.04%   5501      1
# last_sale.transaction.to_account.user.username       79.03%   5503      4
# last_sale.transaction.from_account.user.username     78.94%   5527   3585
# asset_contract.total_supply                          78.41%   5666     22
# collection.display_data.images                       78.15%   5734     18
# collection.instagram_username                        75.54%   6418    606
# collection.telegram_url                              75.19%   6511    197
# asset_contract.payout_address                        74.16%   6781    156
# last_sale.quantity                                   73.89%   6852     47
# last_sale.payment_token.eth_price                    73.64%   6916     18
# last_sale.payment_token.usd_price                    73.64%   6916     18
# last_sale.event_type                                 73.63%   6919      1
# last_sale.payment_token.decimals                     73.63%   6919      6
# last_sale.transaction.to_account.profile_img_url     73.63%   6919     19
# last_sale.payment_token.id                           73.63%   6919     22
# last_sale.payment_token.symbol                       73.63%   6919     22
# last_sale.payment_token.address                      73.63%   6919     22
# last_sale.payment_token.image_url                    73.63%   6919     22
# last_sale.payment_token.name                         73.63%   6919     22
# last_sale.transaction.to_account.address             73.63%   6919     27
# last_sale.transaction.from_account.profile_img_url   73.63%   6919     33
# last_sale.transaction.transaction_index              73.63%   6919    360
# last_sale.total_price                                73.63%   6919   1788
# last_sale.transaction.from_account.address           73.63%   6919   4437
# last_sale.event_timestamp                            73.63%   6919   6599
# last_sale.transaction.block_number                   73.63%   6919   6599
# last_sale.transaction.timestamp                      73.63%   6919   6599
# last_sale.transaction.block_hash                     73.63%   6919   6603
# last_sale.created_date                               73.63%   6919   6911
# last_sale.asset.token_id                             73.63%   6919   6919
# last_sale.transaction.id                             73.63%   6919   6919
# last_sale.transaction.transaction_hash               73.63%   6919   6919
# external_link                                        71.28%   7536   5945
# sell_orders                                          70.58%   7721   7721
# decimals                                             66.28%   8848      1
# collection.discord_url                               63.80%   9499    373
# image_original_url                                   62.40%   9866   8557
# token_metadata                                       61.19%  10185  10101
# asset_contract.opensea_version                       60.00%  10496      3
# asset_contract.description                           59.12%  10728    236
# asset_contract.external_link                         58.42%  10911    230
# asset_contract.image_url                             57.52%  11147    240
# asset_contract.nft_version                           47.60%  13751      3
# collection.external_url                              45.72%  14243   1106
# collection.payout_address                            43.16%  14915   1577
# collection.twitter_username                          42.71%  15034   1230
# collection.featured_image_url                        42.38%  15120   1380
# collection.large_image_url                           35.18%  17009   1422
# description                                          32.29%  17767  11058
# creator.user.username                                30.97%  18114   3008
# collection.banner_image_url                          30.22%  18312   1669
# owner.user.username                                  29.96%  18378   2533
# asset_contract.owner                                 27.19%  19106    199
# name                                                 23.04%  20194  18149
# collection.description                               20.98%  20736   2474
# image_url                                            20.49%  20864  18189
# image_preview_url                                    20.49%  20864  18189
# image_thumbnail_url                                  20.49%  20864  18189
# collection.image_url                                 17.56%  21633   2720
# collection.display_data.card_display_style           16.09%  22020      3
# asset_contract.symbol                                 9.54%  23738    244
# creator.profile_img_url                               1.07%  25960     33
# creator.address                                       1.07%  25960   3698
# asset_contract.dev_buyer_fee_basis_points             0.00%  26241      1
# asset_contract.only_proxied_transfers                 0.00%  26241      1
# asset_contract.opensea_buyer_fee_basis_points         0.00%  26241      1
# asset_contract.buyer_fee_basis_points                 0.00%  26241      1
# collection.dev_buyer_fee_basis_points                 0.00%  26241      1
# collection.is_subject_to_whitelist                    0.00%  26241      1
# collection.only_proxied_transfers                     0.00%  26241      1
# collection.opensea_buyer_fee_basis_points             0.00%  26241      1
# is_presale                                            0.00%  26241      2
# asset_contract.asset_contract_type                    0.00%  26241      2
# asset_contract.default_to_fiat                        0.00%  26241      2
# asset_contract.opensea_seller_fee_basis_points        0.00%  26241      2
# collection.default_to_fiat                            0.00%  26241      2
# collection.featured                                   0.00%  26241      2
# collection.hidden                                     0.00%  26241      2
# collection.opensea_seller_fee_basis_points            0.00%  26241      2
# collection.require_email                              0.00%  26241      2
# asset_contract.schema_name                            0.00%  26241      3
# collection.safelist_request_status                    0.00%  26241      4
# asset_contract.dev_seller_fee_basis_points            0.00%  26241     18
# asset_contract.seller_fee_basis_points                0.00%  26241     18
# owner.profile_img_url                                 0.00%  26241     33
# collection.dev_seller_fee_basis_points                0.00%  26241     56
# num_sales                                             0.00%  26241    206
# asset_contract.name                                   0.00%  26241    279
# asset_contract.created_date                           0.00%  26241    307
# asset_contract.address                                0.00%  26241    308
# collection.created_date                               0.00%  26241   2775
# collection.name                                       0.00%  26241   2782
# collection.slug                                       0.00%  26241   2782
# owner.address                                         0.00%  26241   8069
# traits                                                0.00%  26241  11164
# id                                                    0.00%  26241  26241
# token_id                                              0.00%  26241  26241
# permalink                                             0.00%  26241  26241

# %%
# selecting target columns and desired predictors

df = df_full[[
    # target
    'num_sales', 'sell_orders', 'last_sale.event_type', 
    
    # basic attributes    
    'id', 'token_id', 'name', 'traits', 'description', 'is_presale', 
    'image_url', 'background_color', 'external_link', 'token_metadata',
    
    # asset attributes
    'asset_contract.created_date', 'asset_contract.name', 'asset_contract.description', 'asset_contract.total_supply',
    'asset_contract.symbol', 'asset_contract.schema_name', 'asset_contract.asset_contract_type', 
    'asset_contract.nft_version', 'asset_contract.opensea_version',
    'asset_contract.seller_fee_basis_points', 'asset_contract.dev_seller_fee_basis_points',
    'asset_contract.opensea_seller_fee_basis_points',
    'asset_contract.external_link', 'asset_contract.image_url', 
    
    # collection attributes
    'collection.created_date', 'collection.slug', 'collection.safelist_request_status', 'collection.featured', 
    'collection.description', 'collection.display_data.card_display_style',
    'collection.dev_seller_fee_basis_points', 'collection.opensea_seller_fee_basis_points',
    'collection.external_url', 'collection.image_url', 'collection.large_image_url', 'collection.display_data.images', 
    'collection.twitter_username', 'collection.instagram_username', 'collection.discord_url', 
    'collection.telegram_url', 'collection.medium_username', 'collection.chat_url', 
    
    # creator attributes
    'creator.user.username', 'creator.config', 'creator.profile_img_url', 'creator.discord_id',
    
    # owner attributes
    'owner.address', 'owner.config', 'owner.profile_img_url', 'owner.discord_id' 
    ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26241 entries, 0 to 36100
# Data columns (total 53 columns):
# num_sales                                         26241 non-null int64
# sell_orders                                       7721 non-null object
# last_sale.event_type                              6919 non-null object
# id                                                26241 non-null int64
# token_id                                          26241 non-null object
# name                                              20194 non-null object
# traits                                            26241 non-null object
# description                                       17767 non-null object
# is_presale                                        26241 non-null bool
# image_url                                         20864 non-null object
# background_color                                  2384 non-null object
# external_link                                     7536 non-null object
# token_metadata                                    10185 non-null object
# asset_contract.created_date                       26241 non-null datetime64[ns]
# asset_contract.name                               26241 non-null object
# asset_contract.description                        10728 non-null object
# asset_contract.total_supply                       5666 non-null object
# asset_contract.symbol                             23738 non-null object
# asset_contract.schema_name                        26241 non-null object
# asset_contract.asset_contract_type                26241 non-null object
# asset_contract.nft_version                        13751 non-null object
# asset_contract.opensea_version                    10496 non-null object
# asset_contract.seller_fee_basis_points            26241 non-null int64
# asset_contract.dev_seller_fee_basis_points        26241 non-null int64
# asset_contract.opensea_seller_fee_basis_points    26241 non-null int64
# asset_contract.external_link                      10911 non-null object
# asset_contract.image_url                          11147 non-null object
# collection.created_date                           26241 non-null datetime64[ns]
# collection.slug                                   26241 non-null object
# collection.safelist_request_status                26241 non-null object
# collection.featured                               26241 non-null bool
# collection.description                            20736 non-null object
# collection.display_data.card_display_style        22020 non-null object
# collection.dev_seller_fee_basis_points            26241 non-null int64
# collection.opensea_seller_fee_basis_points        26241 non-null int64
# collection.external_url                           14243 non-null object
# collection.image_url                              21633 non-null object
# collection.large_image_url                        17009 non-null object
# collection.display_data.images                    5734 non-null object
# collection.twitter_username                       15034 non-null object
# collection.instagram_username                     6418 non-null object
# collection.discord_url                            9499 non-null object
# collection.telegram_url                           6511 non-null object
# collection.medium_username                        4039 non-null object
# collection.chat_url                               1292 non-null object
# creator.user.username                             18114 non-null object
# creator.config                                    1459 non-null object
# creator.profile_img_url                           25960 non-null object
# creator.discord_id                                196 non-null object
# owner.address                                     26241 non-null object
# owner.config                                      793 non-null object
# owner.profile_img_url                             26241 non-null object
# owner.discord_id                                  19 non-null object
# dtypes: bool(2), datetime64[ns](2), int64(7), object(42)
# memory usage: 10.5+ MB

# %%
with pd.option_context('display.max_columns', 60):
    display(df.head())
# Out:
#    num_sales                                        sell_orders  \
# 0          0                                                NaN
# 1          0                                                NaN
# 2          0                                                NaN
# 3          0  [{'created_date': '2021-07-13T00:17:14.492573'...
# 4          0  [{'created_date': '2021-07-13T00:17:15.130145'...
#
#   last_sale.event_type        id  \
# 0                  NaN  31278619
# 1                  NaN  31278618
# 2                  NaN  31278617
# 3                  NaN  31278616
# 4                  NaN  31278614
#
#                                             token_id  \
# 0  6715461703434003445645336638579260494260736795...
# 1  3108049546517070910075436470153648977290720661...
# 2  9057683344706687937980539802150068508547322538...
# 3  3268304683559065074852929730958675774624902165...
# 4  7779220728716121010175700030620486582973273824...
#
#                                                 name  \
# 0                    [WordA]Chinese characters #6634
# 1                                    Moosy Rare 1998
# 2  Fortune Cookie # 22   - Unlockable Fortune FOR...
# 3                     IconPunk #243 Ugandan Knuckles
# 4                                  PlagueDoctor #107
#
#                                               traits  \
# 0  [{'trait_type': 'Chinese', 'value': 'character...
# 1  [{'trait_type': 'Level', 'value': 'Rare', 'dis...
# 2                                                 []
# 3  [{'trait_type': 'person', 'value': 'Ugandan Kn...
# 4  [{'trait_type': 'id', 'value': '107', 'display...
#
#                                          description  is_presale  \
# 0  ID:6634 \n\nChinese characters: 柩 // 706  x  7...        True
# 1                                    Moosy Rare 1998        True
# 2  Fortune Cookie # 22\n\nThis collection of uniq...        True
# 3  24x24 pixels and pushing the limit to the max!...        True
# 4  Where are the sick - There I Am. Healing since...        True
#
#                                            image_url background_color  \
# 0  https://lh3.googleusercontent.com/Pd7PXs5ZHtgv...              NaN
# 1  https://lh3.googleusercontent.com/KfteuZFSCiCO...              NaN
# 2  https://lh3.googleusercontent.com/caAUHZLbhExp...              NaN
# 3  https://lh3.googleusercontent.com/4XUpEHLMNbJl...              NaN
# 4  https://lh3.googleusercontent.com/pcJ0zq1Gr-ND...              NaN
#
#   external_link token_metadata asset_contract.created_date  \
# 0           NaN            NaN  2020-12-02 17:40:53.232025
# 1           NaN            NaN  2020-12-02 17:40:53.232025
# 2           NaN            NaN  2020-12-02 17:40:53.232025
# 3           NaN            NaN  2020-12-02 17:40:53.232025
# 4           NaN            NaN  2020-12-02 17:40:53.232025
#
#   asset_contract.name asset_contract.description asset_contract.total_supply  \
# 0  OpenSea Collection                        NaN                         NaN
# 1  OpenSea Collection                        NaN                         NaN
# 2  OpenSea Collection                        NaN                         NaN
# 3  OpenSea Collection                        NaN                         NaN
# 4  OpenSea Collection                        NaN                         NaN
#
#   asset_contract.symbol asset_contract.schema_name  \
# 0             OPENSTORE                    ERC1155
# 1             OPENSTORE                    ERC1155
# 2             OPENSTORE                    ERC1155
# 3             OPENSTORE                    ERC1155
# 4             OPENSTORE                    ERC1155
#
#   asset_contract.asset_contract_type asset_contract.nft_version  \
# 0                      semi-fungible                        NaN
# 1                      semi-fungible                        NaN
# 2                      semi-fungible                        NaN
# 3                      semi-fungible                        NaN
# 4                      semi-fungible                        NaN
#
#   asset_contract.opensea_version  asset_contract.seller_fee_basis_points  \
# 0                          2.0.0                                     250
# 1                          2.0.0                                     250
# 2                          2.0.0                                     250
# 3                          2.0.0                                     250
# 4                          2.0.0                                     250
#
#    asset_contract.dev_seller_fee_basis_points  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    asset_contract.opensea_seller_fee_basis_points  \
# 0                                             250
# 1                                             250
# 2                                             250
# 3                                             250
# 4                                             250
#
#   asset_contract.external_link asset_contract.image_url  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
#
#      collection.created_date                 collection.slug  \
# 0 2021-07-06 08:28:42.215335        worda-chinese-characters
# 1 2021-07-01 22:52:11.315505                the-bullishbears
# 2 2021-07-11 19:59:59.924875  unique-fortune-cookie-fortunes
# 3 2021-05-03 18:55:32.762585                       iconpunks
# 4 2021-05-19 07:24:46.125544                  plaguedoctor-1
#
#   collection.safelist_request_status  collection.featured  \
# 0                      not_requested                False
# 1                      not_requested                False
# 2                      not_requested                False
# 3                      not_requested                False
# 4                      not_requested                False
#
#                               collection.description  \
# 0  The present Chinese characters have evolved fr...
# 1  The Bullish Bears is a 10,000 token NFT projec...
# 2  This collection of unique fortune cookie fortu...
# 3  24x24 pixels and pushing the limit to the max!...
# 4  Where are the sick - There I Am. Healing since...
#
#   collection.display_data.card_display_style  \
# 0                                    contain
# 1                                    contain
# 2                                    contain
# 3                                     padded
# 4                                     padded
#
#    collection.dev_seller_fee_basis_points  \
# 0                                     100
# 1                                    1000
# 2                                      10
# 3                                     500
# 4                                       0
#
#    collection.opensea_seller_fee_basis_points        collection.external_url  \
# 0                                         250                            NaN
# 1                                         250  http://thebullishbearsnft.com
# 2                                         250                            NaN
# 3                                         250                            NaN
# 4                                         250                            NaN
#
#                                 collection.image_url  \
# 0  https://lh3.googleusercontent.com/H_pQIUXGWB7q...
# 1  https://lh3.googleusercontent.com/1dsSBHyqwkMq...
# 2  https://lh3.googleusercontent.com/caAUHZLbhExp...
# 3  https://lh3.googleusercontent.com/2dVGNcqjWQCX...
# 4  https://lh3.googleusercontent.com/ajZlyodqeIqG...
#
#                           collection.large_image_url  \
# 0  https://lh3.googleusercontent.com/vTPDnec7_PuC...
# 1  https://lh3.googleusercontent.com/pzfCIbTxca4F...
# 2  https://lh3.googleusercontent.com/caAUHZLbhExp...
# 3  https://lh3.googleusercontent.com/Y0XW9uG7RyV1...
# 4                                                NaN
#
#   collection.display_data.images collection.twitter_username  \
# 0                            NaN                         NaN
# 1                            NaN             bullishbearsnft
# 2                            NaN                         NaN
# 3                            NaN                    NFTPUNKS
# 4                            NaN                         NaN
#
#   collection.instagram_username collection.discord_url  \
# 0                           NaN                    NaN
# 1            thebullishbearsnft                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#   collection.telegram_url collection.medium_username collection.chat_url  \
# 0                     NaN                        NaN                 NaN
# 1                     NaN                        NaN                 NaN
# 2                     NaN                        NaN                 NaN
# 3                     NaN                        NaN                 NaN
# 4                     NaN                        NaN                 NaN
#
#   creator.user.username creator.config  \
# 0             Suqingyan            NaN
# 1    Thebullishbearsnft            NaN
# 2      FirstThingsFirst            NaN
# 3             iconpunks            NaN
# 4          PlagueDoctor            NaN
#
#                              creator.profile_img_url creator.discord_id  \
# 0  https://storage.googleapis.com/opensea-static/...                NaN
# 1  https://storage.googleapis.com/opensea-static/...                NaN
# 2  https://storage.googleapis.com/opensea-static/...                NaN
# 3  https://storage.googleapis.com/opensea-static/...                NaN
# 4  https://storage.googleapis.com/opensea-static/...                NaN
#
#                                 owner.address owner.config  \
# 0  0x0000000000000000000000000000000000000000          NaN
# 1  0x0000000000000000000000000000000000000000          NaN
# 2  0x0000000000000000000000000000000000000000          NaN
# 3  0x0000000000000000000000000000000000000000          NaN
# 4  0x0000000000000000000000000000000000000000          NaN
#
#                                owner.profile_img_url owner.discord_id
# 0  https://storage.googleapis.com/opensea-static/...              NaN
# 1  https://storage.googleapis.com/opensea-static/...              NaN
# 2  https://storage.googleapis.com/opensea-static/...              NaN
# 3  https://storage.googleapis.com/opensea-static/...              NaN
# 4  https://storage.googleapis.com/opensea-static/...              NaN

# %% [markdown]
# ### Final Output
# - First three columns are target
# - Needs further preprocessing

# %%
df.to_csv('../data/2b_data_condensed_validation_set.csv', index=False)
